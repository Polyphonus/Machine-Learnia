# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

print(pd.__version__)
print(matplotlib.__version__)
print(sns.__version__)
# Out:
# 2.2.3
# 3.9.2
# 0.13.2

# %%
df = sns.load_dataset("mpg")
display(df.head())
display(df.describe())
display(df.info())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# None

# %% [markdown]
# 1. Quelles sont les variables discrètes et continues de ce dataset ?

# %%
discrete_vars = ['cylinders', 'model_year', 'origin', 'name']
continuous_vars = ['mpg', 'displacement', 'horsepower', 'weight', 'acceleration']

# %% [markdown]
# 2. Analysez la variable mpg.

# %%
df['mpg'].describe()
# df['mpg'].nunique()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %% [markdown]
# - Quelle est la moyenne ? Que représente-t'elle vraiment ? (soyez clair et précis !)

# %%
print('La moyenne des consommations de tous les modèles uniques (modèle + motorisation + année de sortie) présents dans les données')
# Out:
# La moyenne des consommations de tous les modèles uniques (modèle + motorisation + année de sortie) présents dans les données

# %% [markdown]
# - Tracez les 2 graphiques utiles pour cette variable

# %%
df['mpg'].plot(kind='hist')
plt.show()

# %%
df['mpg'].plot(kind='box')
plt.show()

# %% [markdown]
# 3. Analysez la variable "cylinders"

# %%
df['cylinders'].describe()
# Out:
# count    398.000000
# mean       5.454774
# std        1.701004
# min        3.000000
# 25%        4.000000
# 50%        4.000000
# 75%        8.000000
# max        8.000000
# Name: cylinders, dtype: float64

# %%
cylinders_uniques = df['cylinders'].unique()
cylinders_uniques.sort()
print(cylinders_uniques)
# Out:
# [3 4 5 6 8]

# %%
sns.countplot(df, x='cylinders')
plt.show()

# %% [markdown]
# 4. Analysez la variable "origin"

# %%
df['origin'].describe()
# Out:
# count     398
# unique      3
# top       usa
# freq      249
# Name: origin, dtype: object

# %%
sns.countplot(df['origin'])
# Out:
# <Axes: xlabel='count', ylabel='origin'>

# %% [markdown]
# 5. Observez l'évolution de la consommation des voitures (mpg) par rapport au nombre de chevaux (horsepower)

# %%
sns.scatterplot(x='horsepower', y='mpg', data=df)
plt.show()

# %% [markdown]
# - Que semble-t-on voir ?

# %%
print('une correlation semble exister entre la puissance et la consommation d\' une voiture')
# Out:
# une correlation semble exister entre la puissance et la consommation d' une voiture

# %% [markdown]
# - Rajoutez-y la variable de l'année du modèle. Que voit-on ?

# %%
sns.scatterplot(x='horsepower', y='mpg', data=df, hue='model_year')
plt.show()

# %% [markdown]
# 6. Observez l'évolution du poids moyen des voitures américaines de l'année 70 jusqu'à l'année 82.

# %% [markdown]
# - Que semble-t-on voir ?
#
# - Voit-on également cela pour les autres pays ?
#
# 7. Analysez la relation entre le nombre de cylindres et l'année du modèle.
#
# - Se dégage-t'il quelque chose de cette analyse ?
#
# 8. Analysez la relation entre le nombre de cylindres et l'origine.
#
# - Se dégage-t'il quelque chose de cette analyse ?
#
# 9. Quelle est l'accélération moyenne des voitures des différents pays ?
#
# 10. Quelle est-elle pour les modèles de l'année 80 ?
#
# 11. Au final Il semblerait qu'une tendance se dégage à travers le temps...
#
# - faites la liste de tous les phénomènes qui semblent se produire (diminution ? augmentation ?) pour les différentes variables et groupes
